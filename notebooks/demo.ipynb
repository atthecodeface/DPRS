# %% [markdown]
# # **Demo Rust integration**

# %%
from dprs import pydp
# Out:
# Directed percolation and other models

# %%
from dprs import sim

# %%
import dprs
dir(dprs)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'pydp',
#  'sim']

# %%
from dprs import sim
print(sim)

n_x = 1_000
n_y = n_x
n_iterations = 200

sim.dp(n_x, n_y, n_iterations)
# Out:
# <module 'dprs.sim' from '/Users/cps/Projects/DPRS/.venv/lib/python3.14/site-packages/dprs/sim.cpython-314-darwin.so'>
# 1000 1000 200
#
# Grid width:  x=1000
# Grid height: y=1000
# Iterations:  n=200
#
#   Serial: 0.916s
# Parallel: 0.105s
# Speedup => 8.74x
# 'Done'
